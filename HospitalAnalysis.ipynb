# %%
from main import DataLoader
from matplotlib import pyplot as plt
from scipy.stats import linregress
import numpy as np
from sklearn import datasets
import pandas as pd
import scipy.stats as stats

# %%
#%matplotlib notebook

# %%
from main import FileHospitalGeneralData
from main import FileHosipitalSpendingNationalData
from main import FilePhysicianData
from main import FilePhysicianNationalData
from main import FilePhysicianGroupMIPSData
from main import FilePhysicianIndivialMIPSData

# %%
hospitalgeneraldata=DataLoader.LoadFile(FileHospitalGeneralData)

# %%
hospitalgeneraldata.head()
# Out:
#   Facility ID                          Facility Name  \
# 0      010001       SOUTHEAST ALABAMA MEDICAL CENTER
# 1      010005  MARSHALL MEDICAL CENTERS SOUTH CAMPUS
# 2      010006           NORTH ALABAMA MEDICAL CENTER
# 3      010007               MIZELL MEMORIAL HOSPITAL
# 4      010008            CRENSHAW COMMUNITY HOSPITAL
#
#                       Address      City State  ZIP Code County Name  \
# 0      1108 ROSS CLARK CIRCLE    DOTHAN    AL     36301     HOUSTON
# 1  2505 U S HIGHWAY 431 NORTH      BOAZ    AL     35957    MARSHALL
# 2         1701 VETERANS DRIVE  FLORENCE    AL     35630  LAUDERDALE
# 3               702 N MAIN ST       OPP    AL     36467   COVINGTON
# 4         101 HOSPITAL CIRCLE   LUVERNE    AL     36049    CRENSHAW
#
#      Phone Number         Hospital Type  \
# 0  (334) 793-8701  Acute Care Hospitals
# 1  (256) 593-8310  Acute Care Hospitals
# 2  (256) 768-8400  Acute Care Hospitals
# 3  (334) 493-3541  Acute Care Hospitals
# ...

# %%
hospitalgeneraldata.columns
# Out:
# Index(['Facility ID', 'Facility Name', 'Address', 'City', 'State', 'ZIP Code',
#        'County Name', 'Phone Number', 'Hospital Type', 'Hospital Ownership',
#        'Emergency Services', 'Meets criteria for meaningful use of EHRs',
#        'Hospital overall rating', 'Hospital overall rating footnote',
#        'Mortality national comparison',
#        'Mortality national comparison footnote',
#        'Safety of care national comparison',
#        'Safety of care national comparison footnote',
#        'Readmission national comparison',
#        'Readmission national comparison footnote',
#        'Patient experience national comparison',
#        'Patient experience national comparison footnote',
#        'Effectiveness of care national comparison',
#        'Effectiveness of care national comparison footnote',
#        'Timeliness of care national comparison',
#        'Timeliness of care national comparison footnote',
# ...

# %%
hospitalrating=pd.DataFrame(hospitalgeneraldata)
i=0
for index,hospital in hospitalrating.iterrows():
       if  hospital["Hospital overall rating"] == '5':
            #print(hospital["Facility Name"]+ "," + hospital["Hospital Ownership"])
            if (i == 0) :
                fivestarhospitals=pd.DataFrame({"Facility Name": [hospital["Facility Name"]],"Hospital Ownership":[hospital["Hospital Ownership"]]})
            else:
                df=pd.DataFrame({"Facility Name": [hospital["Facility Name"]],"Hospital Ownership":[hospital["Hospital Ownership"]]})
                fivestarhospitals=fivestarhospitals.append(df,verify_integrity=False, sort=False,ignore_index=True)
            i = i+1
        #print(str(hospital['Hospital overall rating']))

# %%
fivestarhospitals
# Out:
#                                          Facility Name  \
# 0                               FAYETTE MEDICAL CENTER
# 1                SOUTH BALDWIN REGIONAL MEDICAL CENTER
# 2                          PRATTVILLE BAPTIST HOSPITAL
# 3                          LAKELAND COMMUNITY HOSPITAL
# 4                          BAPTIST MEDICAL CENTER EAST
# ..                                                 ...
# 402        TEXAS HEALTH PRESBYTERIAN HOSPITAL ROCKWALL
# 403                      SOUTH TEXAS SURGICAL HOSPITAL
# 404   TEXAS HEALTH HEART & VASCULAR HOSPITAL ARLINGTON
# 405                         BAPTIST EMERGENCY HOSPITAL
# 406  BAYLOR SCOTT & WHITE MEDICAL CENTER - MARBLE F...
#
#                               Hospital Ownership
# 0                   Voluntary non-profit - Other
# 1                                    Proprietary
# 2    Government - Hospital District or Authority
# 3                  Voluntary non-profit - Church
# 4    Government - Hospital District or Authority
# ...

# %%
hospitalrating=pd.DataFrame(hospitalgeneraldata)
i=0
for index,hospital in hospitalrating.iterrows():
       if  hospital["Hospital overall rating"] == '4':
            #print(hospital["Facility Name"]+ "," + hospital["Hospital Ownership"])
            if (i == 0) :
                fourstarhospitals=pd.DataFrame({"Facility Name": [hospital["Facility Name"]],"Hospital Ownership":[hospital["Hospital Ownership"]]})
            else:
                df=pd.DataFrame({"Facility Name": [hospital["Facility Name"]],"Hospital Ownership":[hospital["Hospital Ownership"]]})
                fourstarhospitals=fourstarhospitals.append(df,verify_integrity=False, sort=False,ignore_index=True)
            i = i+1
        #print(str(hospital['Hospital overall rating']))

# %%
fourstarhospitals
# Out:
#                                           Facility Name  \
# 0                           CRENSHAW COMMUNITY HOSPITAL
# 1                        HELEN KELLER MEMORIAL HOSPITAL
# 2                                   DALE MEDICAL CENTER
# 3                           EAST ALABAMA MEDICAL CENTER
# 4                                COMMUNITY HOSPITAL INC
# ...                                                 ...
# 1128    TEXAS HEALTH HARRIS METHODIST HOSPITAL ALLIANCE
# 1129  BAYLOR SCOTT & WHITE MEDICAL CENTER- COLLEGE S...
# 1130                           RESOLUTE HEALTH HOSPITAL
# 1131                              MEDICAL CITY ALLIANCE
# 1132           HOUSTON METHODIST THE WOODLANDS HOSPITAL
#
#                                Hospital Ownership
# 0                                     Proprietary
# 1     Government - Hospital District or Authority
# 2     Government - Hospital District or Authority
# 3     Government - Hospital District or Authority
# ...

# %%
hospitalrating=pd.DataFrame(hospitalgeneraldata)
i=0
for index,hospital in hospitalrating.iterrows():
       if  hospital["Hospital overall rating"] == '3':
            #print(hospital["Facility Name"]+ "," + hospital["Hospital Ownership"])
            if (i == 0) :
                threestarhospitals=pd.DataFrame({"Facility Name": [hospital["Facility Name"]],"Hospital Ownership":[hospital["Hospital Ownership"]]})
            else:
                df=pd.DataFrame({"Facility Name": [hospital["Facility Name"]],"Hospital Ownership":[hospital["Hospital Ownership"]]})
                threestarhospitals=threestarhospitals.append(df,verify_integrity=False, sort=False,ignore_index=True)
            i = i+1
        #print(str(hospital['Hospital overall rating']))

# %%
threestarhospitals
# Out:
#                                         Facility Name  \
# 0                      LAKE MARTIN COMMUNITY HOSPITAL
# 1                                    FLOWERS HOSPITAL
# 2                                 BIBB MEDICAL CENTER
# 3                              RUSSELL MEDICAL CENTER
# 4                              MEDICAL CENTER BARBOUR
# ...                                               ...
# 1104  BAYLOR SCOTT AND WHITE MEDICAL CENTER SUNNYVALE
# 1105  TEXAS HEALTH PRESBYTERIAN HOSPITAL FLOWER MOUND
# 1106                ST LUKE'S HOSPITAL AT THE VINTAGE
# 1107              SETON MEDICAL CENTER HARKER HEIGHTS
# 1108                  HCA HOUSTON HEALTHCARE PEARLAND
#
#                                Hospital Ownership
# 0                                     Proprietary
# 1                                     Proprietary
# 2     Government - Hospital District or Authority
# 3                  Voluntary non-profit - Private
# 4     Government - Hospital District or Authority
# ...

# %%
hospitalrating=pd.DataFrame(hospitalgeneraldata)
i=0
for index,hospital in hospitalrating.iterrows():
       if  hospital["Hospital overall rating"] == '2':
            #print(hospital["Facility Name"]+ "," + hospital["Hospital Ownership"])
            if (i == 0) :
                twostarhospitals=pd.DataFrame({"Facility Name": [hospital["Facility Name"]],"Hospital Ownership":[hospital["Hospital Ownership"]]})
            else:
                df=pd.DataFrame({"Facility Name": [hospital["Facility Name"]],"Hospital Ownership":[hospital["Hospital Ownership"]]})
                twostarhospitals=twostarhospitals.append(df,verify_integrity=False, sort=False,ignore_index=True)
            i = i+1
        #print(str(hospital['Hospital overall rating']))

# %%
twostarhospitals
# Out:
#                                          Facility Name  \
# 0                     SOUTHEAST ALABAMA MEDICAL CENTER
# 1                MARSHALL MEDICAL CENTERS SOUTH CAMPUS
# 2                         NORTH ALABAMA MEDICAL CENTER
# 3                             MIZELL MEMORIAL HOSPITAL
# 4                                    ST VINCENT'S EAST
# ..                                                 ...
# 697                           BELOIT MEMORIAL HOSPITAL
# 698  ASCENSION SE WISCONSIN HOSPITAL - ST JOSEPH CA...
# 699               INDIANHEAD MEDICAL CENTER SHELL LAKE
# 700                             WYOMING MEDICAL CENTER
# 701   THE HOSPITALS OF PROVIDENCE TRANSMOUNTAIN CAMPUS
#
#                               Hospital Ownership
# 0    Government - Hospital District or Authority
# 1    Government - Hospital District or Authority
# 2                                    Proprietary
# 3                 Voluntary non-profit - Private
# 4                 Voluntary non-profit - Private
# ...

# %%
hospitalrating=pd.DataFrame(hospitalgeneraldata)
i=0
for index,hospital in hospitalrating.iterrows():
       if  hospital["Hospital overall rating"] == '1':
            #print(hospital["Facility Name"]+ "," + hospital["Hospital Ownership"])
            if (i == 0) :
                onestarhospitals=pd.DataFrame({"Facility Name": [hospital["Facility Name"]],"Hospital Ownership":[hospital["Hospital Ownership"]]})
            else:
                df=pd.DataFrame({"Facility Name": [hospital["Facility Name"]],"Hospital Ownership":[hospital["Hospital Ownership"]]})
                onestarhospitals=onestarhospitals.append(df,verify_integrity=False, sort=False,ignore_index=True)
            i = i+1
        #print(str(hospital['Hospital overall rating']))

# %%
onestarhospitals
# Out:
#                              Facility Name  \
# 0                 CHI-ST VINCENT INFIRMARY
# 1                      UAMS MEDICAL CENTER
# 2               ST BERNARDS MEDICAL CENTER
# 3            CONWAY REGIONAL HEALTH SYSTEM
# 4              BAPTIST HEALTH - FORT SMITH
# ..                                     ...
# 222  COLEMAN COUNTY MEDICAL CENTER COMPANY
# 223    BON SECOURS MARYVIEW MEDICAL CENTER
# 224         CHARLESTON AREA MEDICAL CENTER
# 225                      WHEELING HOSPITAL
# 226          ASCENSION ALL SAINTS HOSPITAL
#
#                               Hospital Ownership
# 0                 Voluntary non-profit - Private
# 1                             Government - State
# 2                 Voluntary non-profit - Private
# 3                 Voluntary non-profit - Private
# 4                                    Proprietary
# ..                                           ...
# 222  Government - Hospital District or Authority
# ...

# %%
FSOwnershipCount=pd.DataFrame(fivestarhospitals.groupby("Hospital Ownership").count())
FSOwnershipCount
# Out:
#                                              Facility Name
# Hospital Ownership
# Government - Hospital District or Authority             21
# Government - Local                                      15
# Government - State                                       3
# Physician                                               11
# Proprietary                                             45
# Voluntary non-profit - Church                           42
# Voluntary non-profit - Other                            42
# Voluntary non-profit - Private                         228

# %%
plt.scatter(FSOwnershipCount['Facility Name'],FSOwnershipCount.index,marker="o",color="Black",edgecolor="blue")

# %%
OSOwnershipCount=pd.DataFrame(onestarhospitals.groupby("Hospital Ownership").count())
OSOwnershipCount
# Out:
#                                              Facility Name
# Hospital Ownership
# Government - Federal                                     1
# Government - Hospital District or Authority             18
# Government - Local                                      21
# Government - State                                       7
# Physician                                                3
# Proprietary                                             51
# Voluntary non-profit - Church                           14
# Voluntary non-profit - Other                            14
# Voluntary non-profit - Private                          98

# %%
plt.scatter(OSOwnershipCount['Facility Name'],OSOwnershipCount.index,marker="o",color="Black",edgecolor="blue")

# %%
hospitalownership=hospitalgeneraldata.groupby("Hospital Ownership")
hospitalownership["Hospital Ownership"].count()
# Out:
# Hospital Ownership
# Department of Defense                            35
# Government - Federal                             49
# Government - Hospital District or Authority     538
# Government - Local                              423
# Government - State                              208
# Physician                                        76
# Proprietary                                    1042
# Tribal                                            9
# Voluntary non-profit - Church                   324
# Voluntary non-profit - Other                    411
# Voluntary non-profit - Private                 2224
# Name: Hospital Ownership, dtype: int64

# %%
hospitalownership=hospitalgeneraldata.groupby("Hospital Ownership")
HOCount=hospitalownership["Hospital Ownership"].count()
HOFiveStar=hospitalgeneraldata["Hospital Ownership"][hospitalgeneraldata["Hospital overall rating"] == '5'].value_counts()
HOFourStar=hospitalgeneraldata["Hospital Ownership"][hospitalgeneraldata["Hospital overall rating"] == '4'].value_counts()
HOThreeStar=hospitalgeneraldata["Hospital Ownership"][hospitalgeneraldata["Hospital overall rating"] == '3'].value_counts()
HOTwoStar=hospitalgeneraldata["Hospital Ownership"][hospitalgeneraldata["Hospital overall rating"] == '2'].value_counts()
HOOneStar=hospitalgeneraldata["Hospital Ownership"][hospitalgeneraldata["Hospital overall rating"] == '1'].value_counts()

hospitalratings=pd.DataFrame({"5StarHospitals":HOFiveStar,
                                     "4StarHospitals":HOFourStar,"3StarHospitals":HOThreeStar,
                                     "2StarHospitals":HOTwoStar,"1StarHospitals":HOOneStar,
                                     })
hospitalratings
# Out:
#                                              5StarHospitals  4StarHospitals  \
# Government - Federal                                    NaN             3.0
# Government - Hospital District or Authority            21.0           101.0
# Government - Local                                     15.0            88.0
# Government - State                                      3.0             9.0
# Physician                                              11.0             4.0
# Proprietary                                            45.0           125.0
# Tribal                                                  NaN             NaN
# Voluntary non-profit - Church                          42.0           106.0
# Voluntary non-profit - Other                           42.0           106.0
# Voluntary non-profit - Private                        228.0           591.0
#
#                                              3StarHospitals  2StarHospitals  \
# ...

# %%
hospitalratings = hospitalratings.dropna(axis=0,how="any",thresh=None,subset=None,inplace=False)

# %%
critical_value = stats.chi2.ppf(q = 0.95, df = 7)

# %%
critical_value
# Out:
# 14.067140449340169

# %%
stats.chisquare(f_obs = [hospitalratings['5StarHospitals'], hospitalratings['4StarHospitals'],hospitalratings['3StarHospitals'],hospitalratings['2StarHospitals'],hospitalratings['1StarHospitals']])
# Out:
# Power_divergenceResult(statistic=array([152.53254438,  83.70247934,  10.85714286,   8.61538462,
#        156.62010221,  93.09090909,  92.51515152, 492.92406542]), pvalue=array([5.83403181e-032, 2.85891301e-017, 2.82173261e-002, 7.14658790e-002,
#        7.75720299e-033, 2.90184985e-019, 3.84646284e-019, 2.27199709e-105]))

# %%
# Interpret the test
