# %%
# Import Dependencies
from main import DataLoader
from matplotlib import pyplot as plt
from scipy.stats import linregress
import numpy as np
from sklearn import datasets
import pandas as pd

# %%
from main import OutputFilePhysicianData

# %%
physician_data=DataLoader.LoadFile(OutputFilePhysicianData)
physician_data.head()
# Out:
# C:\Users\jules\Anaconda3\envs\PythonData\lib\site-packages\IPython\core\interactiveshell.py:3242: DtypeWarning: Columns (16) have mixed types. Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):
#           NPI  Individual Pac ID Last Name First Name Gender  \
# 0  1003000134         4284706367    CIBULL     THOMAS      M
# 1  1003000134         4284706367    CIBULL     THOMAS      M
# 2  1003000134         4284706367    CIBULL     THOMAS      M
# 3  1003000134         4284706367    CIBULL     THOMAS      M
# 4  1003000134         4284706367    CIBULL     THOMAS      M
#
#                                Medical School  Graduation Yr  \
# 0  UNIVERSITY OF KENTUCKY COLLEGE OF MEDICINE         2003.0
# 1  UNIVERSITY OF KENTUCKY COLLEGE OF MEDICINE         2003.0
# 2  UNIVERSITY OF KENTUCKY COLLEGE OF MEDICINE         2003.0
# 3  UNIVERSITY OF KENTUCKY COLLEGE OF MEDICINE         2003.0
# 4  UNIVERSITY OF KENTUCKY COLLEGE OF MEDICINE         2003.0
#
#   Primary Speciality                                  Organization Name  \
# 0          PATHOLOGY  NORTHSHORE UNIVERSITY HEALTHSYSTEM FACULTY PRA...
# 1          PATHOLOGY  NORTHSHORE UNIVERSITY HEALTHSYSTEM FACULTY PRA...
# 2          PATHOLOGY  NORTHSHORE UNIVERSITY HEALTHSYSTEM FACULTY PRA...
# 3          PATHOLOGY  NORTHSHORE UNIVERSITY HEALTHSYSTEM FACULTY PRA...
# 4          PATHOLOGY  NORTHSHORE UNIVERSITY HEALTHSYSTEM FACULTY PRA...
#
#    Organization Pac ID  ...  Address ln 2  ln_2_sprs           City State  \
# 0         2.163335e+09  ...           NaN        NaN       GLENVIEW    IL
# 1         2.163335e+09  ...           NaN          Y       GLENVIEW    IL
# 2         2.163335e+09  ...           NaN        NaN  HIGHLAND PARK    IL
# 3         2.163335e+09  ...           NaN        NaN  HIGHALND PARK    IL
# 4         2.163335e+09  ...           NaN          Y       EVANSTON    IL
#
#          Zip     Phone No. Quality Category Score  ACI Category Score  \
# 0  600261301           NaN                   92.6               100.0
# 1  600261301           NaN                   92.6               100.0
# 2  600352433  8.474328e+09                   92.6               100.0
# 3  600352433           NaN                   92.6               100.0
# 4  602011718           NaN                   92.6               100.0
#
#    IA Category Score  Final MIPS Score
# 0               40.0              95.6
# 1               40.0              95.6
# 2               40.0              95.6
# 3               40.0              95.6
# 4               40.0              95.6
#
# [5 rows x 22 columns]

# %%
#Get rows with unique NPIs
unique_pnpi=physician_data.drop_duplicates(subset='NPI',keep="last")
unique_pnpi
# Out:
#                NPI  Individual Pac ID  Last Name First Name Gender  \
# 5       1003000134         4284706367     CIBULL     THOMAS      M
# 7       1003000522         4284705781    WEIGAND  FREDERICK      M
# 8       1003000597         4082848189        KIM        DAE      M
# 10      1003000704         2365611035     GATTON    ZACHARY      M
# 12      1003000902         1153415187     LOHANO   JAIVANTI      F
# ...            ...                ...        ...        ...    ...
# 893919  1992998207         7719179191      SHANE      ANITA      F
# 893920  1992998645          547342438   MARUPUDI  SESHASREE      F
# 893921  1992998736         4880718444    LANGLEY       ADAM      M
# 893923  1992999122         4284728882    JOHNSON    CHARLES      M
# 893928  1992999825          143414284  DESCHENES   GEOFFREY      M
#
#                                            Medical School  Graduation Yr  \
# 5              UNIVERSITY OF KENTUCKY COLLEGE OF MEDICINE         2003.0
# 7                                                   OTHER         1965.0
# 8       STATE UNIVERSITY OF NEW YORK AT BUFFALO SCHOOL...         2007.0
# 10                                                  OTHER         2007.0
# 12                                                  OTHER         1996.0
# ...                                                   ...            ...
# 893919                         BAYLOR COLLEGE OF MEDICINE         2006.0
# 893920                                              OTHER         2001.0
# 893921                                              OTHER         2007.0
# 893923       PHILADELPHIA COLLEGE OF OSTEOPATHIC MEDICINE         1983.0
# 893928  JEFFERSON MEDICAL COLLEGE OF THOMAS JEFFERSON ...         2005.0
#
#        Primary Speciality                                  Organization Name  \
# 5               PATHOLOGY  NORTHSHORE UNIVERSITY HEALTHSYSTEM FACULTY PRA...
# 7         FAMILY MEDICINE           SOUTHWEST VOLUSIA HEALTHCARE CORPORATION
# 8                 UROLOGY                   AHS OKLAHOMA PHYSICIAN GROUP LLC
# 10         ANESTHESIOLOGY                            KNOX COMMUNITY HOSPITAL
# 12        FAMILY MEDICINE                   BAPTIST HEALTH MEDICAL GROUP INC
# ...                   ...                                                ...
# 893919      OPHTHALMOLOGY                     MANATEE SARASOTA EYE CLINIC PA
# 893920  INTERNAL MEDICINE                                                NaN
# 893921    FAMILY MEDICINE            PREMIER FAMILY AND SPORTS MEDICINE, LLC
# 893923  INTERNAL MEDICINE                                                NaN
# 893928     OTOLARYNGOLOGY                      VIRGINIA MASON MEDICAL CENTER
#
#         Organization Pac ID  ...                    Address ln 2  ln_2_sprs  \
# 5              2.163335e+09  ...                             NaN        NaN
# 7              4.461533e+08  ...                       SUITE 200        NaN
# 8              9.436122e+09  ...                       SUITE 701        NaN
# 10             1.153302e+09  ...                            FL 5        NaN
# 12             5.597867e+09  ...  62 LOUISVILLE CARDIOLOGY GROUP        NaN
# ...                     ...  ...                             ...        ...
# 893919         2.466415e+09  ...                             NaN        NaN
# 893920                  NaN  ...                       SUITE 300        NaN
# 893921         9.032361e+09  ...                       SUITE 200        NaN
# 893923                  NaN  ...                       SUITE 155        NaN
# 893928         9.830003e+09  ...   108 VIRGINIA MASON SAND POINT        NaN
#
#                 City State        Zip     Phone No. Quality Category Score  \
# 5           EVANSTON    IL  602014205  8.478691e+09                   92.6
# 7        ORANGE CITY    FL  327638360  3.869178e+09                   93.6
# 8              TULSA    OK  741044019  9.185827e+09                   97.9
# 10      MOUNT VERNON    OH  430501440           NaN                   90.9
# 12           MADISON    IN  472507328  8.128011e+09                   94.6
# ...              ...   ...        ...           ...                    ...
# 893919     BRADENTON    FL  342081931  9.417482e+09                   27.9
# 893920    SHENANDOAH    TX  773843024           NaN                   86.5
# 893921         OCOEE    FL  347614751  4.075819e+09                   92.4
# 893923    BOCA RATON    FL  334875715           NaN                   59.0
# 893928       SEATTLE    WA  981053999  2.065258e+09                  100.0
#
#         ACI Category Score  IA Category Score  Final MIPS Score
# 5                    100.0               40.0              95.6
# 7                    100.0               40.0              96.2
# 8                    100.0               40.0              98.8
# 10                    91.8               40.0              93.0
# 12                    86.7               40.0              93.3
# ...                    ...                ...               ...
# 893919                 0.0                0.0              16.8
# 893920                69.6               40.0              84.1
# 893921                93.0               40.0              93.7
# 893923                93.0               40.0              73.7
# 893928               100.0               40.0             100.0
#
# [334515 rows x 22 columns]

# %%
# GroupBy Physician Gender
grouped_gender=unique_pnpi.groupby(['Gender'])
avg_gendermips=grouped_gender["Final MIPS Score"].mean()
avg_gendermips
# Out:
# Gender
# F    78.551816
# M    76.018787
# Name: Final MIPS Score, dtype: float64

# %%
#Gender distribution of MIPS score
plot = avg_gendermips.plot.pie(figsize=(5,5),autopct='%1.1f%%') 
plt.savefig("./Images/gender_dist_MIPS.png")

# %%
# Create a bar chart based off of the group series 
gender=["Female","Male"]
positions=[0,1]
fig = plt.figure(figsize=(4,4))
plt.bar(positions, avg_gendermips,width=0.6)
plt.xticks(positions,gender,rotation='horizontal')
plt.title("Average MIPS Score by Gender")
plt.xlabel("Physician Gender")
plt.ylabel("Average MIPS Score")
plt.savefig("./Images/gender_AvgMIPS.png")
plt.show()

# %%
# Group MIPS score by State
grouped_state=unique_pnpi.groupby(['State'])
avg_statemips=grouped_state["Final MIPS Score"].mean()
avg_statemips.nlargest(60)
# Out:
# State
# WI    90.617209
# MN    89.509295
# ND    88.888249
# ME    86.630244
# UT    86.010284
# SD    84.817689
# NC    83.969357
# PA    83.863556
# WA    83.779342
# IL    82.811377
# IA    82.591023
# VT    82.275748
# MO    82.227331
# OH    82.222047
# NH    81.916035
# NE    81.846582
# VA    81.750246
# IN    81.387245
# OR    80.728823
# DC    80.474080
# MA    80.313323
# CT    79.987148
# MT    79.895458
# KS    79.439786
# DE    79.394904
# KY    78.929000
# MI    78.691873
# WY    78.525594
# MD    78.339714
# NM    77.609190
# OK    76.485851
# CO    76.473741
# NY    76.328319
# ID    76.075660
# MS    76.061733
# SC    75.997333
# TN    75.990192
# AK    75.625000
# AR    74.719448
# NJ    74.079988
# AZ    73.597423
# WV    72.534509
# GA    71.913395
# LA    70.742203
# AL    70.447188
# CA    69.567536
# TX    69.475189
# NV    69.022143
# HI    68.157962
# FL    67.520327
# GU    67.415789
# RI    62.940909
# MP    61.907143
# VI    37.171429
# PR    13.843551
# Name: Final MIPS Score, dtype: float64

# %%
#ount of MIPS Scores for unique NPI by state
count_statemips=grouped_state["Final MIPS Score"].count()
count_statemips.nlargest(50)
# Out:
# State
# FL    27180
# CA    26466
# TX    22873
# NY    21099
# PA    16705
# IL    13976
# NC    12042
# NJ    12013
# OH    11920
# MI    11283
# GA    10795
# VA     9539
# WA     7624
# MD     7282
# IN     7260
# TN     7015
# MO     6725
# WI     6665
# AZ     6636
# MA     6215
# SC     6111
# CT     5509
# AL     5495
# LA     5194
# KY     5038
# MN     4583
# CO     3892
# OK     3880
# KS     3637
# MS     3635
# AR     3224
# IA     3119
# OR     3015
# UT     2538
# NV     2371
# NE     2209
# WV     2127
# NH     2058
# ME     1964
# NM     1828
# DE     1452
# ID     1364
# MT     1255
# SD     1125
# HI     1099
# VT      936
# ND      851
# RI      770
# WY      758
# AK      720
# Name: Final MIPS Score, dtype: int64

# %%
multi_plot = avg_statemips.plot(kind="bar", figsize=(20,3))
multi_plot.set_ylabel('Average MIPS Score')
multi_plot.set_title('Average MIPS Scores by State')
plt.savefig("./Images/State_AvgMIPS.png")

# %%
# GroupBy Medical School
grouped_medschool=unique_pnpi.groupby(['Medical School'])
avg_medschoolmips=grouped_medschool["Final MIPS Score"].mean()
avg_medschoolmips.nlargest(20)
# Out:
# Medical School
# ATLANTIC MEDICAL COLLEGE                                100.000
# CENTRAL MEDICAL COLLEGE OF ST. JOSEPH - NLG             100.000
# COLLEGE OF PHYSICIANS AND SURGEONS (TENNESSEE)          100.000
# UNIVERSITY OF WOOSTER MEDICAL DEPARTMENT                100.000
# BEAUMONT HOSPITAL MEDIAL COLLEGE - NLG                   99.500
# UNIVERSITY OF ALBERTA FACULTY OF DENTISTRY               99.000
# UNIVERSITY OF COLORADO SCHOOL OF DENTISTRY               99.000
# WILLIAMETTE UNIVERSITY MEDICAL DEPARTMENT                98.600
# FLINT MEDICAL COLLEGE OR NEW ORLEANS UNIVERSITY          98.125
# UNIV OF MISSOURI-KANSAS CITY SCHOOL OF DENTISTRY         97.600
# BALTIMORE UNIVERSITY SCHOOL OF MEDICINE                  97.550
# BOWDOIN MEDICAL SCHOOL                                   97.500
# UNIV OF BRITISH COLUMBIA FACULTY OF DENTISTRY            97.000
# MEDICAL COLLEGE OF GEORGIA SCHOOL OF DENTISTRY           96.850
# COLLEGE OF PHYSICIANS AND SURGEONS (CALIFORNIA)          96.500
# ADIO/PENNSYLVANIA INSTITUTE OF STRAIGHT CHIROPRACTIC     96.200
# UNIVERSITY OF OKLAHOMA COLLEGE OF DENTISTRY              96.200
# CHATTANOOGA MEDICAL COLLEGE                              96.200
# COLLEGE OF PHYSICIANS AND SURGEONS (KANSAS)              96.100
# RESTVIEW CHIROPRACTIC COLLEGE                            95.900
# Name: Final MIPS Score, dtype: float64
